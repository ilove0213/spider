# %%
import requests as req
from bs4 import BeautifulSoup as bs
import os
import random
import re

# 建立下載資料夾（修正：判斷 project_gutenberg）
folder_path = 'project_gutenberg'
os.makedirs(folder_path, exist_ok=True)

# 檢查是否包含中文字的函數
def has_chinese(text: str) -> bool:
    pattern = re.compile(r'[\u4e00-\u9fff]+')
    return bool(pattern.search(text))

# 中文書籍頁面
url = "https://www.gutenberg.org/browse/languages/zh"
res = req.get(url)
soup = bs(res.text, "lxml")

# 收集所有中文書籍連結
book_links = []
for link in soup.find_all('a'):
    if '/ebooks/' in str(link.get('href')):
        title = link.text.strip()
        if has_chinese(title):
            book_links.append({
                'id': link.get('href').split('/')[-1],
                'title': title
            })

print(f"找到 {len(book_links)} 本中文書籍")

# 下載所有中文書籍
selected_books = book_links

for book in selected_books:
    try:
        # 構建下載連結
        download_url = f'https://www.gutenberg.org/files/{book["id"]}/{book["id"]}-0.txt'
        
        # 下載內容
        book_content = req.get(download_url)
        book_content.encoding = 'utf-8'
        
        # 儲存檔案（移除檔名中的特殊字元）
        safe_title = ''.join(c for c in book['title'] if c.isalnum() or c in (' ', '-', '_'))
        file_path = os.path.join(folder_path, f'{safe_title}.txt')
        
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(book_content.text)
        print(f'✅ 成功下載: {book["title"]}')
        
    except Exception as e:
        print(f'❌ 下載 {book["title"]} 失敗: {str(e)}')

print('\n🎉 下載完成！')
# Out:
# 找到 478 本中文書籍
# ✅ 成功下載: 豆棚閒話
# ✅ 成功下載: 戲中戲
# ✅ 成功下載: 比目魚
# ✅ 成功下載: 比目魚
# ✅ 成功下載: 三字經
# ✅ 成功下載: 山水情
# ✅ 成功下載: 山海經
# ✅ 成功下載: 施公案
# ✅ 成功下載: 施公案
# ✅ 成功下載: 易經
# ✅ 成功下載: 木蘭奇女傳
# ✅ 成功下載: 海公案
# ✅ 成功下載: 燕丹子
# ✅ 成功下載: 狄公案
# ✅ 成功下載: 百家姓
# ✅ 成功下載: 禮記
# ✅ 成功下載: 綠牡丹
# ✅ 成功下載: 詩經
# ✅ 成功下載: 麟兒報
# ✅ 成功下載: 天豹圖
# ❌ 下載 梁公九諫 失敗: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ 成功下載: 長恨歌
# ✅ 成功下載: 李娃傳
# ✅ 成功下載: 玉樓春
# ✅ 成功下載: 漢書
# ✅ 成功下載: 引鳳蕭
# ✅ 成功下載: 今古奇觀
# ✅ 成功下載: 後西游記
# ✅ 成功下載: 飛跎全傳
# ✅ 成功下載: 佛說四十二章經
# ✅ 成功下載: 紅樓夢
# ✅ 成功下載: 洛神賦
# ✅ 成功下載: 晁氏儒言 一卷
# ✅ 成功下載: 水滸後傳
# ✅ 成功下載: 幼學瓊林
# ✅ 成功下載: 治世餘聞
# ✅ 成功下載: 琵琶記
# ✅ 成功下載: 雪月梅傳
# ✅ 成功下載: 龍川詞
# ✅ 成功下載: 三國志
# ✅ 成功下載: 隋唐演義
# ✅ 成功下載: 論語
# ✅ 成功下載: 滬語開路 = Conversational Exercises in the Shanghai Dialect
# ✅ 成功下載: 白圭志
# ✅ 成功下載: 孟子字義疏證
# ✅ 成功下載: 安樂集
# ✅ 成功下載: 鄧析子
# ✅ 成功下載: 醉醒石
# ✅ 成功下載: 唐鍾馗平鬼傳
# ✅ 成功下載: 春秋繁露
# ✅ 成功下載: 虬髯客傳
# ✅ 成功下載: 吳船錄
# ✅ 成功下載: 星槎勝覽
# ✅ 成功下載: 星槎勝覽
# ✅ 成功下載: 喻世明言
# ✅ 成功下載: 平妖傳
# ✅ 成功下載: 東周列國志
# ✅ 成功下載: 警世通言
# ✅ 成功下載: 醒世恆言
# ✅ 成功下載: 封氏聞見記
# ✅ 成功下載: 白圭志
# ✅ 成功下載: 搜神記
# ✅ 成功下載: 搜神記 volume 11-14
# ✅ 成功下載: 搜神記 volume 1-3
# ✅ 成功下載: 搜神記 volume 15-17
# ✅ 成功下載: 搜神記 volume 18-20
# ✅ 成功下載: 搜神記 volume 4-10
# ✅ 成功下載: 琵琶記
# ✅ 成功下載: 抱朴子
# ✅ 成功下載: 西京雜記
# ✅ 成功下載: 幽明錄
# ✅ 成功下載: 明鏡公案
# ✅ 成功下載: 公孫龍子
# ✅ 成功下載: 竇娥冤
# ✅ 成功下載: 竇娥寃
# ✅ 成功下載: 管子
# ✅ 成功下載: 管子 — Volume 01 : Chapters 1-5
# ✅ 成功下載: 管子 — Volume 02 : Chapters 6-10
# ✅ 成功下載: 鬼谷子
# ✅ 成功下載: 鬼谷子
# ✅ 成功下載: 穆天子传
# ✅ 成功下載: 漢武帝別國洞冥記
# ✅ 成功下載: 日知錄
# ✅ 成功下載: 海上花列傳
# ✅ 成功下載: 韩非子
# ✅ 成功下載: 風月夢
# ✅ 成功下載: 韓詩外傳
# ✅ 成功下載: 韓詩外傳, Complete
# ✅ 成功下載: 韓詩外傳, Vol. 1-2
# ✅ 成功下載: 韓詩外傳, Vol. 3-4
# ✅ 成功下載: 韓詩外傳, Vol. 5-6
# ✅ 成功下載: 韓詩外傳, Vol. 7-8
# ✅ 成功下載: 韓詩外傳, Vol. 9-10
# ✅ 成功下載: 唐诗三百首
# ✅ 成功下載: 長生殿
# ✅ 成功下載: 菜根譚
# ✅ 成功下載: 菜根譚前後集
# ✅ 成功下載: 天豹圖
# ✅ 成功下載: 筠州黃檗山斷際禪師傳法心要
# ✅ 成功下載: 山水小牘
# ✅ 成功下載: 高士傳
# ✅ 成功下載: 金剛般若波羅蜜經
# ✅ 成功下載: 天妃顯聖錄
# ✅ 成功下載: 三略
# ✅ 成功下載: 明夷待訪錄
# ✅ 成功下載: 鹽鐵論
# ✅ 成功下載: 一枕奇
# ✅ 成功下載: 六祖壇經
# ✅ 成功下載: 臺灣外紀
# ✅ 成功下載: 賈誼新書
# ✅ 成功下載: 金石緣
# ✅ 成功下載: 閱微草堂筆記
# ✅ 成功下載: 醒夢駢言
# ✅ 成功下載: 孔叢子
# ✅ 成功下載: 小爾雅
# ✅ 成功下載: 續世說
# ✅ 成功下載: 桃花扇
# ✅ 成功下載: 金剛般若波羅蜜經
# ✅ 成功下載: 補紅樓夢
# ✅ 成功下載: 老子
# ✅ 成功下載: 道德經
# 唐山過海的故事 臺灣通史
# ✅ 成功下載: 李太白集
# ✅ 成功下載: 李太白集
# ✅ 成功下載: 官場現形記
# ✅ 成功下載: 官場現形記
# ✅ 成功下載: 官場現形記
# ✅ 成功下載: 文明小史
# ✅ 成功下載: 海公案
# ✅ 成功下載: 孫子算經
# ✅ 成功下載: 列子
# ✅ 成功下載: 脾胃論
# ✅ 成功下載: 李賀詩選
# ✅ 成功下載: 文心雕龍
# ✅ 成功下載: 二刻拍案惊奇
# ✅ 成功下載: 二刻拍案驚奇
# ✅ 成功下載: 初刻拍案驚奇
# ✅ 成功下載: 殺子報
# ✅ 成功下載: 天妃顯聖錄
# ✅ 成功下載: 西海紀遊草
# ✅ 成功下載: 西海紀遊草
# ✅ 成功下載: 漱玉詞
# ✅ 成功下載: 鏡花緣
# ✅ 成功下載: 鏡花緣
# ✅ 成功下載: 李義山詩集
# ✅ 成功下載: 天豹圖
# ✅ 成功下載: 梁公九諫
# ✅ 成功下載: 淮南子
# ✅ 成功下載: 天豹圖
# ✅ 成功下載: 老殘遊記
# ✅ 成功下載: 老殘遊記
# ✅ 成功下載: 老殘遊記續集
# ✅ 成功下載: 海島算經
# ✅ 成功下載: 郁離子
# ✅ 成功下載: 人物志
# ✅ 成功下載: 隋唐嘉話
# ✅ 成功下載: 大唐新語
# ✅ 成功下載: 列仙傳
# ✅ 成功下載: 列女傳
# ✅ 成功下載: 新序
# ✅ 成功下載: 說苑
# ✅ 成功下載: 說苑, Volume 13-16
# ✅ 成功下載: 說苑, Volume 1-4
# ✅ 成功下載: 說苑, Volume 17-20
# ✅ 成功下載: 說苑, Volume 5-8
# ✅ 成功下載: 說苑, Volume 9-12
# ✅ 成功下載: 文心雕龍
# ✅ 成功下載: 西京雜記
# ✅ 成功下載: 舊唐書
# ✅ 成功下載: 世說新語
# ✅ 成功下載: 幽明錄
# ✅ 成功下載: 樂章集
# ✅ 成功下載: 斬鬼傳
# ✅ 成功下載: 斬鬼傳
# ✅ 成功下載: 夢中緣
# ✅ 成功下載: 合錦回文傳
# ✅ 成功下載: 無聲戲
# ✅ 成功下載: 肉蒲團
# ✅ 成功下載: 閒情偶寄
# ✅ 成功下載: 闲情偶寄
# ✅ 成功下載: 弟子規
# ✅ 成功下載: 天豹圖
# ✅ 成功下載: 庚巳編
# ✅ 成功下載: 呻吟語
# ✅ 成功下載: 三國志演義
# ✅ 成功下載: 平妖傳
# ✅ 成功下載: 平妖傳
# ✅ 成功下載: 殘唐五代史演義傳
# ✅ 成功下載: 粉妝樓
# ✅ 成功下載: 粉妝樓1-10回
# ✅ 成功下載: 粉妝樓11-20回
# ✅ 成功下載: 粉妝樓21-30回
# ✅ 成功下載: 粉妝樓31-40回
# ✅ 成功下載: 粉妝樓41-50回
# ✅ 成功下載: 粉妝樓51-60回
# ✅ 成功下載: 粉妝樓61-70回
# ✅ 成功下載: 粉妝樓71-80回
# ✅ 成功下載: 粉妝樓全傳
# ✅ 成功下載: 說唐
# ✅ 成功下載: 文心雕龍
# ✅ 成功下載: 常言道
# ✅ 成功下載: 大唐三藏取經詩話
# ✅ 成功下載: 六韜
# ✅ 成功下載: 癡人說夢記
# ✅ 成功下載: 癡人說夢記
# ✅ 成功下載: 封神演義
# ✅ 成功下載: 中國小說史略
# ✅ 成功下載: 南腔北調集
# ✅ 成功下載: 吶喊
# ✅ 成功下載: 徬徨
# ✅ 成功下載: 朝花夕拾
# ✅ 成功下載: 狂人日記
# ✅ 成功下載: 狂人日記
# ✅ 成功下載: 野草
# ✅ 成功下載: 阿Ｑ正傳
# ✅ 成功下載: 文子
# ✅ 成功下載: 老學庵筆記
# ✅ 成功下載: 茶經
# ✅ 成功下載: 茶經
# ✅ 成功下載: 近思錄
# ✅ 成功下載: 瀛涯勝覽
# ✅ 成功下載: 瀛涯勝覽
# ✅ 成功下載: 漢宮秋
# ✅ 成功下載: 孟子
# ✅ 成功下載: 東京夢華錄
# ✅ 成功下載: 白兔記
# ✅ 成功下載: 好逑傳
# ✅ 成功下載: 御製廣寒殿記
# ✅ 成功下載: 墨子
# ✅ 成功下載: 西湖佳話
# ✅ 成功下載: 癡人福
# ✅ 成功下載: 公墓
# ✅ 成功下載: 飲水詞集
# ✅ 成功下載: 春柳鶯
# ✅ 成功下載: 六一詞
# ✅ 成功下載: 歸田錄
# ✅ 成功下載: 三國志
# ✅ 成功下載: 蜀碧
# ✅ 成功下載: 九尾狐
# ✅ 成功下載: 聊齋志異
# ✅ 成功下載: 醒世姻緣
# ✅ 成功下載: 南部新書
# ✅ 成功下載: 東度記
# ✅ 成功下載: 金雲翹傳
# ✅ 成功下載: 拾遺記
# ✅ 成功下載: 負曝閒談
# ✅ 成功下載: 滬語開路 = Conversational Exercises in the Shanghai Dialect
# ✅ 成功下載: 燕子箋
# ✅ 成功下載: 佛說無量壽經
# ✅ 成功下載: 蕉葉帕
# ✅ 成功下載: 商君書
# ✅ 成功下載: 商子
# ✅ 成功下載: 俗話傾談
# ✅ 成功下載: 慎子
# ✅ 成功下載: 浮生六記
# ✅ 成功下載: 枕中記
# ✅ 成功下載: 夢溪筆談
# ✅ 成功下載: 夢溪筆談, Volume 01-06
# ✅ 成功下載: 夢溪筆談, Volume 01-26
# ✅ 成功下載: 夢溪筆談, Volume 07-10
# ✅ 成功下載: 夢溪筆談, Volume 11-16
# ✅ 成功下載: 夢溪筆談, Volume 17-21
# ✅ 成功下載: 夢溪筆談, Volume 22-26
# ✅ 成功下載: 諧鐸
# ✅ 成功下載: 六祖壇經
# ✅ 成功下載: 幽閨記
# ✅ 成功下載: 水滸傳
# ✅ 成功下載: 文子
# ✅ 成功下載: 三俠五義
# ✅ 成功下載: 史記
# ✅ 成功下載: 司馬法
# ✅ 成功下載: 灵历集光
# ✅ 成功下載: 灵历集光
# ✅ 成功下載: 莊子的故事
# ✅ 成功下載: 天工開物
# ✅ 成功下載: 歸蓮夢
# ✅ 成功下載: 錦香亭
# ✅ 成功下載: 杜陽雜編
# ✅ 成功下載: 斷鴻零雁記
# ✅ 成功下載: 北夢瑣言
# ✅ 成功下載: 兵法 (Bīng Fǎ)
# ✅ 成功下載: 孫子兵法
# ✅ 成功下載: 孫子算經
# ✅ 成功下載: 東坡志林
# ✅ 成功下載: 東坡樂府
# ✅ 成功下載: 水調歌頭
# ✅ 成功下載: 蘇洵集
# ✅ 成功下載: 孫子兵法道家新註解
# ✅ 成功下載: 牡丹亭
# ✅ 成功下載: 彭公案
# ✅ 成功下載: 五孝傳
# ✅ 成功下載: 搜神後記
# ✅ 成功下載: 搜神後記. Selections. 1985
# ✅ 成功下載: 轟天雷
# ✅ 成功下載: 人間樂
# ✅ 成功下載: 定情人
# ✅ 成功下載: 平山冷燕
# ✅ 成功下載: 玉嬌梨
# ✅ 成功下載: 玉支机
# ✅ 成功下載: 玉雙魚
# ✅ 成功下載: 畫圖緣
# ✅ 成功下載: 石點頭
# ✅ 成功下載: 商界現形記
# ✅ 成功下載: 合錦回文傳
# ✅ 成功下載: 玉蟾記
# ✅ 成功下載: 宋史
# ✅ 成功下載: 周髀算經
# ✅ 成功下載: 天豹圖
# ✅ 成功下載: 孔雀東南飛
# ✅ 成功下載: 孝經
# ✅ 成功下載: 文子
# ✅ 成功下載: 明鏡公案
# ✅ 成功下載: 春秋配
# ✅ 成功下載: 梁公九諫
# ✅ 成功下載: 爾雅
# ✅ 成功下載: 竹書紀年
# ✅ 成功下載: 黄帝宅經
# ✅ 成功下載: 大唐三藏取經詩話
# ✅ 成功下載: 文淵閣四庫全書
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 43
#      40 download_url = f'https://www.gutenberg.org/files/{book["id"]}/{book["id"]}-0.txt'
#      42 # 下載內容
# ---> 43 book_content = req.get(download_url)
#      44 book_content.encoding = 'utf-8'
#      46 # 儲存檔案（移除檔名中的特殊字元）
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     738     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     739     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742         sock=sock,
#     743         cert_reqs=self.cert_reqs,
#     744         ssl_version=self.ssl_version,
#     745         ssl_minimum_version=self.ssl_minimum_version,
#     746         ssl_maximum_version=self.ssl_maximum_version,
#     747         ca_certs=self.ca_certs,
#     748         ca_cert_dir=self.ca_cert_dir,
#     749         ca_cert_data=self.ca_cert_data,
#     750         cert_file=self.cert_file,
#     751         key_file=self.key_file,
#     752         key_password=self.key_password,
#     753         server_hostname=server_hostname_rm_dot,
#     754         ssl_context=self.ssl_context,
#     755         tls_in_tls=tls_in_tls,
#     756         assert_hostname=self.assert_hostname,
#     757         assert_fingerprint=self.assert_fingerprint,
#     758     )
#     759     self.sock = sock_and_verified.socket
#     761 # If an error occurs during connection/handshake we may need to release
#     762 # our lock so another connection can probe the origin.
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connection.py:920, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     917     if is_ipaddress(normalized):
#     918         server_hostname = normalized
# --> 920 ssl_sock = ssl_wrap_socket(
#     921     sock=sock,
#     922     keyfile=key_file,
#     923     certfile=cert_file,
#     924     key_password=key_password,
#     925     ca_certs=ca_certs,
#     926     ca_cert_dir=ca_cert_dir,
#     927     ca_cert_data=ca_cert_data,
#     928     server_hostname=server_hostname,
#     929     ssl_context=context,
#     930     tls_in_tls=tls_in_tls,
#     931 )
#     933 try:
#     934     if assert_fingerprint:
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\util\ssl_.py:460, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456         context.load_cert_chain(certfile, keyfile, key_password)
#     458 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 460 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     461 return ssl_sock
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\site-packages\urllib3\util\ssl_.py:504, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     501     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     502     return SSLTransport(sock, ssl_context, server_hostname)
# --> 504 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1101         if timeout == 0.0:
#    1102             # non-blocking
#    1103             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104         self.do_handshake()
#    1105 except (OSError, ValueError):
#    1106     self.close()
#
# File c:\Users\empty\anaconda3\envs\web_scraping\lib\ssl.py:1375, in SSLSocket.do_handshake(self, block)
#    1373     if timeout == 0.0 and block:
#    1374         self.settimeout(None)
# -> 1375     self._sslobj.do_handshake()
#    1376 finally:
#    1377     self.settimeout(timeout)
#
# KeyboardInterrupt:
